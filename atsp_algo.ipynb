# %%
import networkx as nx
import networkx.algorithms.approximation as approx
from networkx.algorithms.tree.mst import random_spanning_tree
import tsplib95
import numpy as np
import pulp
from math import exp, log as ln, ceil
import math
import time

# %%
def solve(k):
    problem = tsplib95.load("data/p43.atsp")
    G = problem.get_graph()
    G.is_directed() 


    # only keep weights: (i,j,{'weight': weight, 'is_fixed": True}) -> G[i][j] = weight
    for u, v, data in G.edges(data=True):
        weight = data.get('weight', 0)  
        G[u][v].clear()  
        G[u][v]['weight'] = weight

    # making sure G is complete

    for i in G.nodes:
        for j in G.nodes:
            if i != j and not G.has_edge(i, j):
                G.add_edge(i, j, weight=9999)
                print(f"[!] added edge {i} {j} with weight 9999")
                
    G = G.subgraph(list(G.nodes)[:k])
    # print edges in a matrix


    start = time.time()


    def find_violated_cut(G, x_vals):
        """
        Finds a violated cut constraint using a max-flow/min-cut approach.

        Parameters:
            G (nx.DiGraph): The directed graph.
            x_vals (dict): Current LP solution values for edges.

        Returns:
            U (set): A subset of nodes violating the cut constraint, or None if no violation.
        """
        residual = nx.DiGraph()
        for (u, v), val in x_vals.items():
            residual.add_edge(u, v, capacity=val)

        # check for violated cuts for each pair of source and sink nodes
        for source in G.nodes:
            for sink in G.nodes:
                if source != sink:
                    cut_value, (reachable, non_reachable) = nx.minimum_cut(
                        residual, source, sink, capacity='capacity'
                    )
                    
                    if cut_value < 1:
                        return reachable  # violated subset as reachable nodes
        return None  

    def HK(G):
        """
        Compute the Held-Karp relaxation for the ATSP using a separation oracle.

        Parameters:
            G (nx.DiGraph): Directed graph with 'weight' attributes on edges.

        Returns:
            objective (float): The optimal objective value.
            z_star (dict): Symmetrized solution of the Held-Karp relaxation.
        """
        if not G.is_directed():
            raise ValueError("Graph must be a directed graph (DiGraph).")

        V = list(G.nodes)
        A = list(G.edges)
        c = nx.get_edge_attributes(G, 'weight')

        prob = pulp.LpProblem("Held-Karp_Relaxation", pulp.LpMinimize)
        x = pulp.LpVariable.dicts("x", A, lowBound=0, cat='Continuous')

        prob += pulp.lpSum([c[arc] * x[arc] for arc in A]), "Total_Cost"

        # flow conservation constraints (3.3)
        for v in V:
            prob += pulp.lpSum([x[(v, w)] for w in G.successors(v)]) == 1, f"Outflow_{v}"
            prob += pulp.lpSum([x[(u, v)] for u in G.predecessors(v)]) == 1, f"Inflow_{v}"

        constraint_counter = 0
        while True:
            prob.solve()

            # find support graph
            x_vals = {arc: (x[arc].varValue or 0) for arc in A}

            # use separation oracle to find violated cut if any
            violated_cut = find_violated_cut(G, x_vals)
            if violated_cut is None:
                break  # good

            # hash names
            delta_plus_U = [(u, v) for u in violated_cut for v in G.successors(u) if v not in violated_cut]
            prob += pulp.lpSum([x[arc] for arc in delta_plus_U]) >= 1, f"Cut_{constraint_counter}"
            constraint_counter += 1  


        x_star = {arc: (x[arc].varValue or 0) for arc in A}

        # symmetrize solution to get z_star (3.5)
        z_star = {}
        scale_factor = (len(V) - 1) / len(V)  # (n-1)/n scaling factor from paper
        for (u, v) in A:
            frequency = x_star[(u, v)] + x_star.get((v, u), 0)
            if frequency > 0:
                z_star[(u, v)] = scale_factor * frequency

        # sanity check for connectivity
        support_graph = nx.Graph()
        for (u, v), val in z_star.items():
            if val > 0:
                support_graph.add_edge(u, v)

        if not nx.is_connected(support_graph):
            raise ValueError("Held-Karp solution produced disconnected support graph!")

        return pulp.value(prob.objective), z_star


    HK_opt, z_star = HK(G)



    def q_(G, gamma):
        node_list = list(G.nodes())
        node_index = {node: i for i, node in enumerate(node_list)}
        
        for u, v, d in G.edges(data=True):
            d["lambda"] = exp(gamma[(u, v)])
        
        L = nx.laplacian_matrix(G, weight='lambda').toarray()

        L_pinv = np.linalg.pinv(L)
        
        q = {}
        for u, v, d in G.edges(data=True):
            ui, vi = node_index[u], node_index[v]
            R_uv = L_pinv[ui, ui] + L_pinv[vi, vi] - 2 * L_pinv[ui, vi]
            q[(u, v)] = d['lambda'] * R_uv
        
        return q



    def spanning_tree_distribution(G, z):
        gamma = {arc: 0 for arc in G.edges()}

        EPSILON = 0.2

        while True:
            # search for an edge with q_e > (1 + epsilon) * z_e
            for e in gamma.keys():
                q_e = q_(G, gamma)[e]
                z_e = z[e]
                if q_e > (1 + EPSILON) * z_e:
                    # lemma 7.1
                    delta = ln(
                        (q_e * (1 - (1 + EPSILON / 2) * z_e))
                        / ((1 - q_e) * (1 + EPSILON / 2) * z_e)
                    )
                    # check that delta had the desired effect on q
                    # we decrease gamma_e in order to decrease qe(gamma) to (1 +epsilon/2) * ze
                    gamma[e] -= delta
                    new_q_e = q_(G, gamma)[e]
                    desired_q_e = (1 + EPSILON / 2) * z_e
                    if round(new_q_e, 8) != round(desired_q_e, 8):
                        raise nx.NetworkXError(
                            f"Unable to modify probability for edge ({u}, {v})"
                        )
            q = q_(G, gamma)
            if all(q[e] <= (1 + EPSILON) * z[e] for e in G.edges()):
                break

        # remove lambda from edge attribute: not needed anymore
        for _, _, d in G.edges(data=True):
            if "lambda" in d:
                del d["lambda"]

        return gamma


    z_support = nx.MultiGraph()
    for u, v in z_star:
        if (u, v) not in z_support.edges:
            edge_weight = min(G[u][v]['weight'], G[v][u]['weight'])
            z_support.add_edge(u, v, weight=edge_weight)



    gamma = spanning_tree_distribution(z_support, z_star)


    z_support = nx.Graph(z_support)
    lambda_dict = {(u, v): exp(gamma[(u, v)]) for u, v in z_support.edges()}
    nx.set_edge_attributes(z_support, lambda_dict, "weight")
    # del gamma, lambda_dict

    # sample 2 * ceil( ln(n) ) spanning trees and record the minimum one
    minimum_sampled_tree = None
    minimum_sampled_tree_weight = math.inf
    for _ in range(2 * ceil(ln(G.number_of_nodes()))):
        sampled_tree = random_spanning_tree(z_support, "weight", seed=None)
        sampled_tree_weight = sampled_tree.size(weight)
        if sampled_tree_weight < minimum_sampled_tree_weight:
            minimum_sampled_tree = sampled_tree.copy()
            minimum_sampled_tree_weight = sampled_tree_weight

    # orient the edge
    t_star = nx.MultiDiGraph()
    for u, v, d in minimum_sampled_tree.edges(data=weight):
        if d == G[u][v]['weight']:
            t_star.add_edge(u, v, weight=d)
        else:
            t_star.add_edge(v, u, weight=d)

    node_demands = {n: t_star.out_degree(n) - t_star.in_degree(n) for n in t_star}
    nx.set_node_attributes(G, node_demands, "demand")

    # demand graph based on in/out degree imbalance
    flow_dict = nx.min_cost_flow(G, "demand")

    for source, values in flow_dict.items():
        for target in values:
            if (source, target) not in t_star.edges and values[target] > 0:
                # IF values[target] > 0 we have to add that many edges
                for _ in range(values[target]):
                    t_star.add_edge(source, target)
    circuit = nx.eulerian_circuit(t_star, source=source)





    def shortcutting(circuit):
        """Remove duplicate nodes in the path"""
        nodes = []
        for u, v in circuit:
            if v in nodes:
                continue
            if not nodes:
                nodes.append(u)
            nodes.append(v)
        nodes.append(nodes[0])
        return nodes


        
    ans = shortcutting(circuit)


    total_cost = 0
    for i in range(len(ans)-1):
        total_cost += G[ans[i]][ans[i+1]]['weight']

    print(f"total cost: {total_cost}")
    print(ans)
    total_time = time.time() - start

    return total_cost, total_time

# %%
import json

try:
    with open('ans.json', 'r') as file:
        ans = json.load(file)
except FileNotFoundError:
    ans = {}

for i in range(34, 0, -1):
    for repeat in range(5):
        total_cost, runtime = solve(int(i))
        key = str(i) 
        if key not in ans:
            ans[key] = {"total_cost": [], "runtime": []}
        if total_cost not in ans[key]["total_cost"]:
            ans[key]["total_cost"].append(total_cost)
        if runtime not in ans[key]["runtime"]:
            ans[key]["runtime"].append(runtime)
        with open('ans.json', 'w') as file:
            json.dump(ans, file, indent=4)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/00829673d77e4272827531337e4da5f6-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/00829673d77e4272827531337e4da5f6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 85 COLUMNS
# At line 4792 RHS
# At line 4873 BOUNDS
# At line 4874 ENDATA
# Problem MODEL has 80 rows, 1600 columns and 3200 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 80 (0) rows, 1600 (0) columns and 3200 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.25462867%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 79.999992 (80)
# 58  Obj 0.071328331
# Optimal - objective value 0
# Optimal objective 0 - 58 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/9541cef5978347bc8932b3c254aa937d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/9541cef5978347bc8932b3c254aa937d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 86 COLUMNS
# At line 4904 RHS
# At line 4986 BOUNDS
# At line 4987 ENDATA
# Problem MODEL has 81 rows, 1600 columns and 3311 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 81 (0) rows, 1600 (0) columns and 3311 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.29309998%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 80.999992 (81)
# 63  Obj 2.0689985
# Optimal - objective value 2
# Optimal objective 2 - 63 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/948b2ba32b724a2da83f957508f2f491-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/948b2ba32b724a2da83f957508f2f491-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 87 COLUMNS
# At line 5049 RHS
# At line 5132 BOUNDS
# At line 5133 ENDATA
# Problem MODEL has 82 rows, 1600 columns and 3455 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 82 (0) rows, 1600 (0) columns and 3455 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.25462867%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 81.999992 (82)
# 62  Obj 2.0685967
# Optimal - objective value 2
# Optimal objective 2 - 62 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/e9cf40cddfde42bc8d15453149abf042-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/e9cf40cddfde42bc8d15453149abf042-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 88 COLUMNS
# At line 5225 RHS
# At line 5309 BOUNDS
# At line 5310 ENDATA
# Problem MODEL has 83 rows, 1600 columns and 3630 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 83 (0) rows, 1600 (0) columns and 3630 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.25462867%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 82.999992 (83)
# 62  Obj 2.069976
# Optimal - objective value 2
# Optimal objective 2 - 62 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/c94d80faca63483ab8ed3eecd49771c6-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/c94d80faca63483ab8ed3eecd49771c6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 89 COLUMNS
# At line 5370 RHS
# At line 5455 BOUNDS
# At line 5456 ENDATA
# Problem MODEL has 84 rows, 1600 columns and 3774 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 84 (0) rows, 1600 (0) columns and 3774 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.25462867%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 83.999992 (84)
# 65  Obj 4.0689789
# Optimal - objective value 4
# Optimal objective 4 - 65 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/30caaa44dfdb44338b2a0475b41ee5a4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/30caaa44dfdb44338b2a0475b41ee5a4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 90 COLUMNS
# At line 5575 RHS
# At line 5661 BOUNDS
# At line 5662 ENDATA
# Problem MODEL has 85 rows, 1600 columns and 3978 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 85 (0) rows, 1600 (0) columns and 3978 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.25462867%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 84.999992 (85)
# 67  Obj 12.068591
# Optimal - objective value 12
# Optimal objective 12 - 67 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/4527db2df3104524a3fe290461a39520-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/4527db2df3104524a3fe290461a39520-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 91 COLUMNS
# At line 5687 RHS
# At line 5774 BOUNDS
# At line 5775 ENDATA
# Problem MODEL has 86 rows, 1600 columns and 4089 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 86 (0) rows, 1600 (0) columns and 4089 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.29309998%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 85.999991 (86)
# 72  Obj 12.0663
# Optimal - objective value 12
# Optimal objective 12 - 72 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/84fce7745ed548ffa7cc485b6e4f4c3a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/84fce7745ed548ffa7cc485b6e4f4c3a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 92 COLUMNS
# At line 5863 RHS
# At line 5951 BOUNDS
# At line 5952 ENDATA
# Problem MODEL has 87 rows, 1600 columns and 4264 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 87 (0) rows, 1600 (0) columns and 4264 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.26676341%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 86.999991 (87)
# 66  Obj 12.065452
# Optimal - objective value 12
# Optimal objective 12 - 66 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/e685c52c8db04fdeaaf84f4c2f55e127-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/e685c52c8db04fdeaaf84f4c2f55e127-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 93 COLUMNS
# At line 6068 RHS
# At line 6157 BOUNDS
# At line 6158 ENDATA
# Problem MODEL has 88 rows, 1600 columns and 4468 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 88 (0) rows, 1600 (0) columns and 4468 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.25462867%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 87.999991 (88)
# 72  Obj 14.062872
# Optimal - objective value 14
# Optimal objective 14 - 72 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/2d3d33f1084a4a188c82875d7b38f2cf-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/2d3d33f1084a4a188c82875d7b38f2cf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 94 COLUMNS
# At line 6348 RHS
# At line 6438 BOUNDS
# At line 6439 ENDATA
# Problem MODEL has 89 rows, 1600 columns and 4747 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 89 (0) rows, 1600 (0) columns and 4747 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.25462867%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 88.999991 (89)
# 72  Obj 8.0645676 Primal inf 13.999999 (11)
# 76  Obj 14.061682
# Optimal - objective value 14
# Optimal objective 14 - 76 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/9f743f13d43d44a7ad8a51cb6b9e3274-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/9f743f13d43d44a7ad8a51cb6b9e3274-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 95 COLUMNS
# At line 6649 RHS
# At line 6740 BOUNDS
# At line 6741 ENDATA
# Problem MODEL has 90 rows, 1600 columns and 5047 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 90 (0) rows, 1600 (0) columns and 5047 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.25462867%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 89.999991 (90)
# 71  Obj 14.063171
# Optimal - objective value 14
# Optimal objective 14 - 71 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/79c9900ff87147e0a09f6e405acce0a5-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/79c9900ff87147e0a09f6e405acce0a5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 96 COLUMNS
# At line 6825 RHS
# At line 6917 BOUNDS
# At line 6918 ENDATA
# Problem MODEL has 91 rows, 1600 columns and 5222 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 91 (0) rows, 1600 (0) columns and 5222 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.25462867%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 90.999991 (91)
# 74  Obj 14.063401
# Optimal - objective value 14
# Optimal objective 14 - 74 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/5bb207aab8ed4ec58c47c41978b8c5de-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/5bb207aab8ed4ec58c47c41978b8c5de-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 97 COLUMNS
# At line 7057 RHS
# At line 7150 BOUNDS
# At line 7151 ENDATA
# Problem MODEL has 92 rows, 1600 columns and 5453 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 92 (0) rows, 1600 (0) columns and 5453 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.26595905%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 91.999991 (92)
# 73  Obj 14.064426
# Optimal - objective value 14
# Optimal objective 14 - 73 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/f8cccdd5beeb4ea1ac0aa96676e8f1de-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/f8cccdd5beeb4ea1ac0aa96676e8f1de-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 98 COLUMNS
# At line 7202 RHS
# At line 7296 BOUNDS
# At line 7297 ENDATA
# Problem MODEL has 93 rows, 1600 columns and 5597 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 93 (0) rows, 1600 (0) columns and 5597 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.26595905%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 92.999991 (93)
# 72  Obj 11.061473 Primal inf 10.999999 (10)
# 77  Obj 14.063385
# Optimal - objective value 14
# Optimal objective 14 - 77 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/73648efef1804518810b99c2305a4978-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/73648efef1804518810b99c2305a4978-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 99 COLUMNS
# At line 7378 RHS
# At line 7473 BOUNDS
# At line 7474 ENDATA
# Problem MODEL has 94 rows, 1600 columns and 5772 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 94 (0) rows, 1600 (0) columns and 5772 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.26595905%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 93.999991 (94)
# 70  Obj 10.06294 Primal inf 9.9999991 (9)
# 80  Obj 14.729866
# Optimal - objective value 14.666667
# Optimal objective 14.66666667 - 80 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/3225bbb90fb246ed9d6cd31372394031-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/3225bbb90fb246ed9d6cd31372394031-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 100 COLUMNS
# At line 7698 RHS
# At line 7794 BOUNDS
# At line 7795 ENDATA
# Problem MODEL has 95 rows, 1600 columns and 6091 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 95 (0) rows, 1600 (0) columns and 6091 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.25462867%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 94.999991 (95)
# 76  Obj 11.060436 Primal inf 5.4999992 (8)
# 85  Obj 16.062679
# Optimal - objective value 16
# Optimal objective 16 - 85 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/28fa2336d24e4e1a89786ed585be1afe-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/28fa2336d24e4e1a89786ed585be1afe-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 101 COLUMNS
# At line 8018 RHS
# At line 8115 BOUNDS
# At line 8116 ENDATA
# Problem MODEL has 96 rows, 1600 columns and 6410 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 96 (0) rows, 1600 (0) columns and 6410 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.25462867%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 95.99999 (96)
# 76  Obj 12.062444 Primal inf 4.9999995 (5)
# 88  Obj 17.061997
# Optimal - objective value 17
# Optimal objective 17 - 88 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/7aabd4b74ea14977a7af8fa404b31caa-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/7aabd4b74ea14977a7af8fa404b31caa-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 102 COLUMNS
# At line 8275 RHS
# At line 8373 BOUNDS
# At line 8374 ENDATA
# Problem MODEL has 97 rows, 1600 columns and 6666 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 97 (0) rows, 1600 (0) columns and 6666 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.25462867%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 96.99999 (97)
# 76  Obj 16.06108 Primal inf 12.999999 (12)
# 89  Obj 20.061942
# Optimal - objective value 20
# Optimal objective 20 - 89 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/1c18c61993fa4a3ab44f6f5e9d63ae5f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/1c18c61993fa4a3ab44f6f5e9d63ae5f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 103 COLUMNS
# At line 8507 RHS
# At line 8606 BOUNDS
# At line 8607 ENDATA
# Problem MODEL has 98 rows, 1600 columns and 6897 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 98 (0) rows, 1600 (0) columns and 6897 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.25462867%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 97.99999 (98)
# 76  Obj 18.062303 Primal inf 2.9999997 (3)
# 88  Obj 20.060818
# Optimal - objective value 20
# Optimal objective 20 - 88 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/8e1e43ceb894478d91f8c85d011f52fd-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/8e1e43ceb894478d91f8c85d011f52fd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 104 COLUMNS
# At line 8547 RHS
# At line 8647 BOUNDS
# At line 8648 ENDATA
# Problem MODEL has 99 rows, 1600 columns and 6936 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 99 (0) rows, 1600 (0) columns and 6936 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.25462867%) - largest zero change 0.0027035139
# 0  Obj 0 Primal inf 98.99999 (99)
# 76  Obj 12.062213 Primal inf 2.9999997 (3)
# 91  Obj 20.061209
# Optimal - objective value 20
# Optimal objective 20 - 91 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/b7440a50198547dea5b3e5c4d63aa5a7-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/b7440a50198547dea5b3e5c4d63aa5a7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 105 COLUMNS
# At line 8827 RHS
# At line 8928 BOUNDS
# At line 8929 ENDATA
# Problem MODEL has 100 rows, 1600 columns and 7215 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 100 (0) rows, 1600 (0) columns and 7215 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.25462867%) - largest zero change 0.0027035139
# 0  Obj 0 Primal inf 99.99999 (100)
# 75  Obj 11.060441 Primal inf 2.9999997 (3)
# 90  Obj 20.059797
# Optimal - objective value 20
# Optimal objective 20 - 90 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/5d0c325cccd5479ab8200132ed903b4b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/5d0c325cccd5479ab8200132ed903b4b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 106 COLUMNS
# At line 9084 RHS
# At line 9186 BOUNDS
# At line 9187 ENDATA
# Problem MODEL has 101 rows, 1600 columns and 7471 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 101 (0) rows, 1600 (0) columns and 7471 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.25462867%) - largest zero change 0.0027035139
# 0  Obj 0 Primal inf 100.99999 (101)
# 74  Obj 11.0597 Primal inf 3.9999996 (4)
# 90  Obj 20.059147
# Optimal - objective value 20
# Optimal objective 20 - 90 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/caab1b0f6765459b886a7ccffcdb38cc-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/caab1b0f6765459b886a7ccffcdb38cc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 107 COLUMNS
# At line 9385 RHS
# At line 9488 BOUNDS
# At line 9489 ENDATA
# Problem MODEL has 102 rows, 1600 columns and 7771 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 102 (0) rows, 1600 (0) columns and 7771 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.30001257%) - largest zero change 0.0027035139
# 0  Obj 0 Primal inf 101.99999 (102)
# 77  Obj 13.056331 Primal inf 7.9999992 (8)
# 91  Obj 21.057671
# Optimal - objective value 21
# Optimal objective 21 - 91 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/906f0906f3124a99826dd49906e7f7c8-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/906f0906f3124a99826dd49906e7f7c8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 108 COLUMNS
# At line 9770 RHS
# At line 9874 BOUNDS
# At line 9875 ENDATA
# Problem MODEL has 103 rows, 1600 columns and 8155 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 103 (0) rows, 1600 (0) columns and 8155 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.25462867%) - largest zero change 0.0027035139
# 0  Obj 0 Primal inf 102.99999 (103)
# 76  Obj 13.059368 Primal inf 2.9999997 (3)
# 90  Obj 22.056999
# Optimal - objective value 22
# Optimal objective 22 - 90 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/e67cbc36729d407394ae0e411362f25a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/e67cbc36729d407394ae0e411362f25a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 109 COLUMNS
# At line 10135 RHS
# At line 10240 BOUNDS
# At line 10241 ENDATA
# Problem MODEL has 104 rows, 1600 columns and 8519 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 104 (0) rows, 1600 (0) columns and 8519 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.25462867%) - largest zero change 0.0027035139
# 0  Obj 0 Primal inf 103.99999 (104)
# 74  Obj 15.058337 Primal inf 3.9999996 (4)
# 83  Obj 22.055756
# Optimal - objective value 22
# Optimal objective 22 - 83 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/d9718e16f16443649ecc8490268f28cb-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/d9718e16f16443649ecc8490268f28cb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 110 COLUMNS
# At line 10520 RHS
# At line 10626 BOUNDS
# At line 10627 ENDATA
# Problem MODEL has 105 rows, 1600 columns and 8903 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 105 (0) rows, 1600 (0) columns and 8903 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.25462867%) - largest zero change 0.0027035139
# 0  Obj 0 Primal inf 104.99999 (105)
# 75  Obj 14.059334 Primal inf 3.9999996 (4)
# 96  Obj 24.054528
# Optimal - objective value 24
# Optimal objective 24 - 96 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/4188e2e851d14acb9b4f1acb86666ec3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/4188e2e851d14acb9b4f1acb86666ec3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 111 COLUMNS
# At line 10597 RHS
# At line 10704 BOUNDS
# At line 10705 ENDATA
# Problem MODEL has 106 rows, 1600 columns and 8979 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 106 (0) rows, 1600 (0) columns and 8979 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.25462867%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 105.99999 (106)
# 77  Obj 14.056934 Primal inf 3.9999996 (4)
# 106  Obj 24.052889
# Optimal - objective value 24
# Optimal objective 24 - 106 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/3c190b7e5b2b49e992799877cbf98d2c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/3c190b7e5b2b49e992799877cbf98d2c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 112 COLUMNS
# At line 10934 RHS
# At line 11042 BOUNDS
# At line 11043 ENDATA
# Problem MODEL has 107 rows, 1600 columns and 9315 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 107 (0) rows, 1600 (0) columns and 9315 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.25462867%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 106.99999 (107)
# 77  Obj 14.056736 Primal inf 2.9999997 (3)
# 100  Obj 24.053668
# Optimal - objective value 24
# Optimal objective 24 - 100 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/8c31a2251d554d61b4b116bfc3f7eb02-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/8c31a2251d554d61b4b116bfc3f7eb02-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 11326 RHS
# At line 11435 BOUNDS
# At line 11436 ENDATA
# Problem MODEL has 108 rows, 1600 columns and 9706 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 108 (0) rows, 1600 (0) columns and 9706 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.25462867%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 107.99999 (108)
# 77  Obj 19.054736 Primal inf 4.9999995 (5)
# 89  Obj 24.057055
# Optimal - objective value 24
# Optimal objective 24 - 89 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/8f27d6cdf497463699101c53ebad4d47-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/8f27d6cdf497463699101c53ebad4d47-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 114 COLUMNS
# At line 11583 RHS
# At line 11693 BOUNDS
# At line 11694 ENDATA
# Problem MODEL has 109 rows, 1600 columns and 9962 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 109 (0) rows, 1600 (0) columns and 9962 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.2813674%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 108.99999 (109)
# 77  Obj 13.059687 Primal inf 13.999999 (13)
# 97  Obj 24.056283
# Optimal - objective value 24
# Optimal objective 24 - 97 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/54c69cef6f8f485e91912d63c214a5ac-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/54c69cef6f8f485e91912d63c214a5ac-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 115 COLUMNS
# At line 11815 RHS
# At line 11926 BOUNDS
# At line 11927 ENDATA
# Problem MODEL has 110 rows, 1600 columns and 10193 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 110 (0) rows, 1600 (0) columns and 10193 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.25462867%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 109.99999 (110)
# 71  Obj 12.055615 Primal inf 9.999999 (10)
# 102  Obj 24.055292
# Optimal - objective value 24
# Optimal objective 24 - 102 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/f31e10b4496c4d29813aaa01de9a2839-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/f31e10b4496c4d29813aaa01de9a2839-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 116 COLUMNS
# At line 12095 RHS
# At line 12207 BOUNDS
# At line 12208 ENDATA
# Problem MODEL has 111 rows, 1600 columns and 10472 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 111 (0) rows, 1600 (0) columns and 10472 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.25462867%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 110.99999 (111)
# 76  Obj 13.0572 Primal inf 34.999997 (26)
# 107  Obj 25.053249 Primal inf 1.2499995 (5)
# 111  Obj 25.254009
# Optimal - objective value 25.2
# Optimal objective 25.2 - 111 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/b9de256f28ec46d592bc029dcc7d5cb5-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/b9de256f28ec46d592bc029dcc7d5cb5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 117 COLUMNS
# At line 12492 RHS
# At line 12605 BOUNDS
# At line 12606 ENDATA
# Problem MODEL has 112 rows, 1600 columns and 10868 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 112 (0) rows, 1600 (0) columns and 10868 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.2813674%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 111.99999 (112)
# 75  Obj 14.053934 Primal inf 52.999997 (26)
# 96  Obj 26.053071
# Optimal - objective value 26
# Optimal objective 26 - 96 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/2f219a05da554b27b49233acddf056e8-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/2f219a05da554b27b49233acddf056e8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 118 COLUMNS
# At line 12868 RHS
# At line 12982 BOUNDS
# At line 12983 ENDATA
# Problem MODEL has 113 rows, 1600 columns and 11243 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 113 (0) rows, 1600 (0) columns and 11243 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.2813674%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 112.99999 (113)
# 72  Obj 14.052544 Primal inf 6.9999993 (7)
# 110  Obj 26.053502 Primal inf 3.9999996 (4)
# 132  Obj 28.052069
# Optimal - objective value 28
# Optimal objective 28 - 132 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/d51cdedb99e7488e9faced32f4353f33-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/d51cdedb99e7488e9faced32f4353f33-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 119 COLUMNS
# At line 13253 RHS
# At line 13368 BOUNDS
# At line 13369 ENDATA
# Problem MODEL has 114 rows, 1600 columns and 11627 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 114 (0) rows, 1600 (0) columns and 11627 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.2813674%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 113.99999 (114)
# 75  Obj 17.055611 Primal inf 10.999999 (11)
# 87  Obj 32.056825
# Optimal - objective value 32
# Optimal objective 32 - 87 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/a12f8c91ef474cbab71b2f69c3a2ae92-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/a12f8c91ef474cbab71b2f69c3a2ae92-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 120 COLUMNS
# At line 13429 RHS
# At line 13545 BOUNDS
# At line 13546 ENDATA
# Problem MODEL has 115 rows, 1600 columns and 11802 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 115 (0) rows, 1600 (0) columns and 11802 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.2813674%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 114.99999 (115)
# 57  Obj 16.043089 Primal inf 22.999998 (21)
# 98  Obj 32.055309
# Optimal - objective value 32
# Optimal objective 32 - 98 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/66266068ba8943bc919c57760e95e4f4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/66266068ba8943bc919c57760e95e4f4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 121 COLUMNS
# At line 13634 RHS
# At line 13751 BOUNDS
# At line 13752 ENDATA
# Problem MODEL has 116 rows, 1600 columns and 12006 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 116 (0) rows, 1600 (0) columns and 12006 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.2813674%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 115.99999 (116)
# 76  Obj 23.052613 Primal inf 17.999998 (16)
# 86  Obj 32.055451
# Optimal - objective value 32
# Optimal objective 32 - 86 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/7c289ae5a1134c4c8d3600f545f0921b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/7c289ae5a1134c4c8d3600f545f0921b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 122 COLUMNS
# At line 13779 RHS
# At line 13897 BOUNDS
# At line 13898 ENDATA
# Problem MODEL has 117 rows, 1600 columns and 12150 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 117 (0) rows, 1600 (0) columns and 12150 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.2813674%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 116.99999 (117)
# 76  Obj 19.053613 Primal inf 3.9999996 (4)
# 88  Obj 33.053915
# Optimal - objective value 33
# Optimal objective 33 - 88 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/a6bed0a671904dda9b4424cb8c7520d1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/a6bed0a671904dda9b4424cb8c7520d1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 123 COLUMNS
# At line 13984 RHS
# At line 14103 BOUNDS
# At line 14104 ENDATA
# Problem MODEL has 118 rows, 1600 columns and 12354 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 118 (0) rows, 1600 (0) columns and 12354 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.2813674%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 117.99999 (118)
# 50  Obj 16.032531 Primal inf 46.999996 (40)
# 99  Obj 23.053619 Primal inf 9.999999 (10)
# 113  Obj 33.054399
# Optimal - objective value 33
# Optimal objective 33 - 113 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/c4bc9467d8e04acfb170f5309f540524-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/c4bc9467d8e04acfb170f5309f540524-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 124 COLUMNS
# At line 14160 RHS
# At line 14280 BOUNDS
# At line 14281 ENDATA
# Problem MODEL has 119 rows, 1600 columns and 12529 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 119 (0) rows, 1600 (0) columns and 12529 (0) elements
# Perturbing problem by 0.001% of 5104 - largest nonzero change 0.0030295582 ( 0.2813674%) - largest zero change 0.0025527287
# 0  Obj 0 Primal inf 118.99999 (119)
# 76  Obj 17.055243 Primal inf 5.9999994 (6)
# 103  Obj 33.388325
# Optimal - objective value 33.333333
# Optimal objective 33.33333333 - 103 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/1e74fe5f75824b949afc19de7464dd22-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/1e74fe5f75824b949afc19de7464dd22-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 125 COLUMNS
# At line 14461 RHS
# At line 14582 BOUNDS
# At line 14583 ENDATA
# Problem MODEL has 120 rows, 1600 columns and 12829 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 120 (0) rows, 1600 (0) columns and 12829 (0) elements
# ...
# 49  Obj 44.020469 Primal inf 301.99998 (166)
# 130  Obj 140.05805 Primal inf 126.66666 (100)
# 187  Obj 169.05235 Primal inf 126.99999 (90)
# 236  Obj 176.05369
# Optimal - objective value 176
# Optimal objective 176 - 236 iterations time 0.012
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.04   (Wallclock seconds):       0.05
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/8789e72ec11a475c91cfba7952a8fef1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/8789e72ec11a475c91cfba7952a8fef1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 349 COLUMNS
# At line 96112 RHS
# At line 96457 BOUNDS
# At line 96458 ENDATA
# Problem MODEL has 344 rows, 1849 columns and 94016 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 344 (0) rows, 1849 (0) columns and 94016 (0) elements
# Perturbing problem by 0.001% of 5160 - largest nonzero change 0.0061366415 ( 0.60380635%) - largest zero change 0.0061116478
# 0  Obj 0 Primal inf 343.99997 (344)
# 40  Obj 37.014618 Primal inf 216.99999 (149)
# 121  Obj 140.04771 Primal inf 158.33332 (132)
# 171  Obj 161.0526 Primal inf 67.999994 (56)
# 225  Obj 175.05419 Primal inf 3.4999996 (4)
# 243  Obj 176.05373
# Optimal - objective value 176
# Optimal objective 176 - 243 iterations time 0.012
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.04   (Wallclock seconds):       0.05
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/8af6c7f6c837465db390074009815659-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/8af6c7f6c837465db390074009815659-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 350 COLUMNS
# At line 96573 RHS
# At line 96919 BOUNDS
# At line 96920 ENDATA
# Problem MODEL has 345 rows, 1849 columns and 94476 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 345 (0) rows, 1849 (0) columns and 94476 (0) elements
# Perturbing problem by 0.001% of 5160 - largest nonzero change 0.0061366415 ( 0.60380635%) - largest zero change 0.0061116478
# 0  Obj 0 Primal inf 344.99997 (345)
# 43  Obj 43.022546 Primal inf 293.99998 (161)
# 121  Obj 138.05831 Primal inf 117.99999 (102)
# 168  Obj 162.06351 Primal inf 266.99999 (113)
# 219  Obj 176.05305 Primal inf 2.9999997 (3)
# 231  Obj 176.05384
# Optimal - objective value 176
# Optimal objective 176 - 231 iterations time 0.012
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.04   (Wallclock seconds):       0.05
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/745a6baebb6a493795881822495e1713-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/745a6baebb6a493795881822495e1713-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 351 COLUMNS
# At line 97034 RHS
# At line 97381 BOUNDS
# At line 97382 ENDATA
# Problem MODEL has 346 rows, 1849 columns and 94936 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 346 (0) rows, 1849 (0) columns and 94936 (0) elements
# Perturbing problem by 0.001% of 5160 - largest nonzero change 0.0061366415 ( 0.60380635%) - largest zero change 0.0061116478
# 0  Obj 0 Primal inf 345.99997 (346)
# 81  Obj 120.05272 Primal inf 62.999992 (83)
# 139  Obj 158.04252 Primal inf 54.999996 (37)
# 190  Obj 176.05388
# Optimal - objective value 176
# Optimal objective 176 - 190 iterations time 0.012
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.04   (Wallclock seconds):       0.05
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/2bfdd76e648d4c6293dd6fadb80cc167-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/2bfdd76e648d4c6293dd6fadb80cc167-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 352 COLUMNS
# At line 97485 RHS
# At line 97833 BOUNDS
# At line 97834 ENDATA
# Problem MODEL has 347 rows, 1849 columns and 95386 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 347 (0) rows, 1849 (0) columns and 95386 (0) elements
# Perturbing problem by 0.001% of 5160 - largest nonzero change 0.0061366415 ( 0.60380635%) - largest zero change 0.0061116478
# 0  Obj 0 Primal inf 346.99997 (347)
# 44  Obj 39.242814 Primal inf 265.77776 (171)
# 115  Obj 119.05761 Primal inf 373.99998 (156)
# 166  Obj 157.05058 Primal inf 245.99999 (110)
# 219  Obj 175.05568 Primal inf 6.4999993 (7)
# 239  Obj 176.05489
# Optimal - objective value 176
# Optimal objective 176 - 239 iterations time 0.012
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.04   (Wallclock seconds):       0.05
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/292fd24ea099402f8e580bf244a343fe-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/292fd24ea099402f8e580bf244a343fe-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 353 COLUMNS
# At line 97936 RHS
# At line 98285 BOUNDS
# At line 98286 ENDATA
# Problem MODEL has 348 rows, 1849 columns and 95836 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 348 (0) rows, 1849 (0) columns and 95836 (0) elements
# Perturbing problem by 0.001% of 5160 - largest nonzero change 0.0061366415 ( 0.60380635%) - largest zero change 0.0061116478
# 0  Obj 0 Primal inf 347.99997 (348)
# 50  Obj 39.017658 Primal inf 283.49998 (180)
# 131  Obj 137.05878 Primal inf 449.99998 (158)
# 175  Obj 168.05447 Primal inf 21.999998 (15)
# 223  Obj 176.05661 Primal inf 16.999998 (17)
# 234  Obj 177.0527
# Optimal - objective value 177
# Optimal objective 177 - 234 iterations time 0.012
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.05   (Wallclock seconds):       0.05
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/c91d971cb96744bfb63bdb786f120b05-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/c91d971cb96744bfb63bdb786f120b05-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 354 COLUMNS
# At line 98343 RHS
# At line 98693 BOUNDS
# At line 98694 ENDATA
# Problem MODEL has 349 rows, 1849 columns and 96242 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 349 (0) rows, 1849 (0) columns and 96242 (0) elements
# Perturbing problem by 0.001% of 5160 - largest nonzero change 0.0061366415 ( 0.60380635%) - largest zero change 0.0061116478
# 0  Obj 0 Primal inf 348.99997 (349)
# 54  Obj 124.02873 Primal inf 230.99998 (159)
# 135  Obj 145.0507 Primal inf 357.99999 (126)
# 180  Obj 178.05198
# Optimal - objective value 178
# Optimal objective 178 - 180 iterations time 0.012
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.04   (Wallclock seconds):       0.05
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/a06972f5390c4da8a06e61e883bab3db-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/a06972f5390c4da8a06e61e883bab3db-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 355 COLUMNS
# At line 98804 RHS
# At line 99155 BOUNDS
# At line 99156 ENDATA
# Problem MODEL has 350 rows, 1849 columns and 96702 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 350 (0) rows, 1849 (0) columns and 96702 (0) elements
# Perturbing problem by 0.001% of 5160 - largest nonzero change 0.0061366415 ( 0.60380635%) - largest zero change 0.0061116478
# 0  Obj 0 Primal inf 349.99996 (350)
# 60  Obj 62.01798 Primal inf 228.99999 (150)
# 137  Obj 159.05144 Primal inf 126.99999 (85)
# 184  Obj 178.05198 Primal inf 0.9999999 (1)
# 185  Obj 178.05201
# Optimal - objective value 178
# Optimal objective 178 - 185 iterations time 0.012
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.04   (Wallclock seconds):       0.05
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/03a6bf5c3a684e8e895e70ce3807f6fd-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/03a6bf5c3a684e8e895e70ce3807f6fd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 356 COLUMNS
# At line 99267 RHS
# At line 99619 BOUNDS
# At line 99620 ENDATA
# Problem MODEL has 351 rows, 1849 columns and 97164 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 351 (0) rows, 1849 (0) columns and 97164 (0) elements
# Perturbing problem by 0.001% of 5160 - largest nonzero change 0.0061366415 ( 0.60380635%) - largest zero change 0.0061116478
# 0  Obj 0 Primal inf 350.99996 (351)
# 61  Obj 119.03442 Primal inf 101.99999 (76)
# 138  Obj 141.20661 Primal inf 118.15383 (116)
# 191  Obj 168.05163 Primal inf 8.9999991 (9)
# 213  Obj 180.04922
# Optimal - objective value 180
# Optimal objective 180 - 213 iterations time 0.012
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.04   (Wallclock seconds):       0.05
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/22fb8201949e4f24a95cf38d8f6ec8b0-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/22fb8201949e4f24a95cf38d8f6ec8b0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 357 COLUMNS
# At line 99710 RHS
# At line 100063 BOUNDS
# At line 100064 ENDATA
# Problem MODEL has 352 rows, 1849 columns and 97606 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 352 (0) rows, 1849 (0) columns and 97606 (0) elements
# Perturbing problem by 0.001% of 5160 - largest nonzero change 0.0061366415 ( 0.60380635%) - largest zero change 0.0061116478
# 0  Obj 0 Primal inf 351.99996 (352)
# 43  Obj 49.011282 Primal inf 316.49998 (179)
# 116  Obj 125.05313 Primal inf 99.62499 (97)
# 177  Obj 169.0555 Primal inf 12.999999 (13)
# 205  Obj 180.05133
# Optimal - objective value 180
# Optimal objective 180 - 205 iterations time 0.012
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.05   (Wallclock seconds):       0.05
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/5f5f914aea204470b27016f2925fc902-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/5f5f914aea204470b27016f2925fc902-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 358 COLUMNS
# At line 100173 RHS
# At line 100527 BOUNDS
# At line 100528 ENDATA
# Problem MODEL has 353 rows, 1849 columns and 98068 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 353 (0) rows, 1849 (0) columns and 98068 (0) elements
# Perturbing problem by 0.001% of 5160 - largest nonzero change 0.0061366415 ( 0.60380635%) - largest zero change 0.0061116478
# 0  Obj 0 Primal inf 352.99996 (353)
# 57  Obj 68.017363 Primal inf 254.99998 (173)
# 139  Obj 128.54529 Primal inf 153.49999 (94)
# 197  Obj 165.06032 Primal inf 79.499993 (71)
# 247  Obj 180.05136
# Optimal - objective value 180
# Optimal objective 180 - 247 iterations time 0.012
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.05   (Wallclock seconds):       0.05
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/94ce65f5b43c4bc983d60bc250a7f10a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/94ce65f5b43c4bc983d60bc250a7f10a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 359 COLUMNS
# At line 100630 RHS
# At line 100985 BOUNDS
# At line 100986 ENDATA
# Problem MODEL has 354 rows, 1849 columns and 98524 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 354 (0) rows, 1849 (0) columns and 98524 (0) elements
# Perturbing problem by 0.001% of 5160 - largest nonzero change 0.0061366415 ( 0.60380635%) - largest zero change 0.0061116478
# 0  Obj 0 Primal inf 353.99996 (354)
# 42  Obj 42.014743 Primal inf 151.99999 (148)
# 124  Obj 125.55159 Primal inf 205.99998 (153)
# 176  Obj 170.30515 Primal inf 29.374994 (60)
# 226  Obj 180.05185
# Optimal - objective value 180
# Optimal objective 180 - 226 iterations time 0.012
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.05   (Wallclock seconds):       0.05
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/FakeYQL/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/db672d3b1d1b4a9eadd6329224ab0b22-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4s/2ly7t48j4r57l9zmt1db4qgw0000gn/T/db672d3b1d1b4a9eadd6329224ab0b22-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 360 COLUMNS
# At line 101073 RHS
# At line 101429 BOUNDS
# At line 101430 ENDATA
# Problem MODEL has 355 rows, 1849 columns and 98966 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 355 (0) rows, 1849 (0) columns and 98966 (0) elements
# Perturbing problem by 0.001% of 5160 - largest nonzero change 0.0061366415 ( 0.60380635%) - largest zero change 0.0061116478
# 0  Obj 0 Primal inf 354.99996 (355)
# 51  Obj 63.04333 Primal inf 433.99998 (194)
# 126  Obj 151.0573 Primal inf 467.99998 (175)
# 179  Obj 169.05639 Primal inf 130.99999 (67)
# 234  Obj 180.05196 Primal inf 1.4999998 (2)
# 238  Obj 180.05218
# Optimal - objective value 180
# Optimal objective 180 - 238 iterations time 0.012
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.05   (Wallclock seconds):       0.05
